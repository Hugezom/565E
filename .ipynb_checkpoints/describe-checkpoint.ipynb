# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as ss
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv("cleaned.csv")

# %%
total_transactions = df.groupby("block_number").apply(lambda x:x.n_transaction.iloc[0])

# %%
symbol_counts.sum()
# Out:
# 248811

# %%
symbol_counts = df.symbol.value_counts()
plt.figure(figsize=(8*1.5,8), dpi=300)
top_n = 10
X = np.arange(top_n)+1
symbols = symbol_counts.index[:top_n]
n_transactions = symbol_counts.iloc[:top_n].values
plt.bar(X, n_transactions)
plt.xticks(X, symbols)
for x, value in zip(X, n_transactions):
    plt.text(x, value+500, value, ha='center')
plt.savefig("MDEX中交易数量排名前10币对.jpg", bbox_inches="tight")

# %%
des = [ss.describe(df.gas_price)]
for symbol in symbol_counts.index[:-1]:
    symbol_df = df[df.symbol==symbol]
    des.append(ss.describe(symbol_df.gas_price))
des = pd.DataFrame(des, index=["Total"]+symbol_counts.index[:-1].tolist())

# %%
des.to_csv("76个币对GAS价格描述.csv")

# %%
tmp = des.iloc[1:].sort_values("mean", ascending=False)
plt.figure(figsize=(12,8), dpi=300)
top_n = 10
X = np.arange(top_n)+1
symbols = tmp.index[:top_n]
n_transactions = tmp["mean"].iloc[:top_n].values
plt.bar(X, n_transactions)
plt.xticks(X, symbols)
for x, value in zip(X, n_transactions):
    plt.text(x, value+1, round(value, 4), ha='center')
plt.savefig("MDEX中GAS价格均值排名前10币对.jpg", bbox_inches="tight")

# %%
tmp = des.iloc[1:].sort_values("variance", ascending=False)
plt.figure(figsize=(12,8), dpi=300)
top_n = 10
X = np.arange(top_n)+1
symbols = tmp.index[:top_n]
n_transactions = tmp["variance"].iloc[:top_n].values
plt.bar(X, n_transactions)
plt.xticks(X, symbols)
for x, value in zip(X, n_transactions):
    plt.text(x, value+400, round(value, 2), ha='center')
plt.savefig("MDEX中GAS价格方差排名前10币对.jpg", bbox_inches="tight")

# %%
unverified_ratio = df.groupby("symbol")["can_abi"].apply(lambda x:1-x.sum()/x.count())
unverified_ratio.name = "unverified_ratio"

total_number = df.groupby("symbol")["can_abi"].count()
total_number.name = "total_number"

unverified_number = total_number-df.groupby("symbol")["can_abi"].sum()
unverified_number.name = "unverified_number"

unverified_info = pd.DataFrame([unverified_ratio, unverified_number, total_number]).T
unverified_info.to_csv("各币对加密合约统计.csv")

# %%
pd.DataFrame([unverified_ratio, unverified_number], columns=[])
# Out:
# symbol     AAVE/USDT   ADA/USDT   BAL/USDT  BIFI/USDT      BNB/HT  \
# can_abi     0.964304    0.43121   0.052239   0.244094    0.582602
# can_abi  3755.000000  467.00000  42.000000  62.000000  797.000000
#
# symbol      BTC/USDT     CAN/MDX  DAI/USDC    DAI/USDT     DOG/USDT  ...  \
# can_abi     0.631355    0.966102       1.0    0.790634     0.762369  ...
# can_abi  3564.000000  228.000000      16.0  861.000000  1094.000000  ...
#
# symbol      USDT/HPT     USDT/JT     USDT/LTC  USDT/NULS   USDT/PIPI  \
# can_abi     0.760554    0.835821     0.851877      0.745    0.671642
# can_abi  2360.000000  168.000000  2542.000000    298.000  225.000000
#
# symbol     USDT/SHIB     USDT/YFI    WOO/USDT    XRP/USDT  ZT/USDT
# can_abi     0.641953     0.952171    0.820979    0.561594      0.0
# can_abi  2130.000000  1294.000000  587.000000  310.000000      0.0
#
# [2 rows x 77 columns]

# %%
ht_gas = df[df.symbol=="HT/USDT"]["gas_price"]

# %%
df
# Out:
#                                                      hash  block_number  \
# 0       0x13923927cc3aa068ba4b4a157767dbfe18e913f58aa2...       8959243
# 1       0x6352459c3d213a9223410bb3284d2d8370ea088451d7...       8959242
# 2       0x48aa38644550830c1981f1a3cf1e7a330dbca7a0302a...       8959242
# 3       0xddb7ddc26ee5f931c88859d024aaf3be05130857b69a...       8959242
# 4       0xf6ad449a42674c53c980258a6f4bf307b7f2902fa78b...       8959242
# ...                                                   ...           ...
# 248806  0xaeca7b32541c2dea13f76eb0f910a621e186654f108f...       8524547
# 248807  0x98ee0427262da68e8fbd55cce48723ba8c4cec254191...       8524547
# 248808  0x8a4892a30cf6186da42d71191522e2551df2ea75ad96...       8524547
# 248809  0x163479f044858d9da75b4e6572fa59a3d30fa2cf797d...       8524545
# 248810  0x72523d08c06e2856424b836b11879738eb94c95fadeb...       8524544
#
#         n_transaction     timestamp  \
# 0                  23  1.633772e+12
# 1                  33  1.633772e+12
# 2                  33  1.633772e+12
# 3                  33  1.633772e+12
# 4                  33  1.633772e+12
# ...               ...           ...
# 248806             34  1.632640e+12
# 248807             34  1.632640e+12
# 248808             34  1.632640e+12
# 248809             30  1.632640e+12
# 248810             36  1.632640e+12
#
#                                                      from  \
# 0       0xb62c710f0420d59cb7900bc0413676db56519f130xb6...
# 1       0xaa3e34c024271c476a979fafc181aadb9d8ecffd0xaa...
# 2       0xaa3e34c024271c476a979fafc181aadb9d8ecffd0xaa...
# 3       0x066919da59e43062756896dd1fa64ef9f0d46ae20x06...
# 4       0x3eaf7de168a79c1d6a1aab8c106e42b6f4e0a7c80x3e...
# ...                                                   ...
# 248806  0x5ec278e9371826b7e44ae3cfcb5cedda99d3afb50x5e...
# 248807  0xfac3f783264c95e60955bd0c6af1e71b94b0079d0xfa...
# 248808  0xf5cb768dd0689b5fafd84347a548811e68bbb9450xf5...
# 248809  0xa75a408919cba06088992923a71bee839a06ce240xa7...
# 248810  0xbb077238550572b2a60f3b76373e00ace1baeefd0xbb...
#
#                                                        to   status  \
# 0       0xe0584102e595a5a6792f6dd82cc9cf2676fcea670xe0...  Success
# 1       0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
# 2       0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
# 3       0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
# 4       0x2979f9c20f75891070f23f950700906551a560c60x29...  Success
# ...                                                   ...      ...
# 248806  0xb01a9a7ef5779fa8680898827cc2b1aed638ee2d0xb0...  Success
# 248807  0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
# 248808  0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
# 248809  0x3b9ea0ac211cdb5f81343f0c34bdf8922f668e150x3b...  Success
# 248810  0xed7d5f38c79115ca12fe6c0041abb22f0a06c3000xed...  Success
#
#         transferred_value  transferred_number  gas_limit  gas_used  gas_price  \
# 0                   12.58                  19  5000000.0    723343      2.250
# 1                  690.00                   2  2100000.0    144550     41.000
# 2                  530.33                   2  2100000.0    144526     41.000
# 3                 2931.04                   3  7000000.0    213362      6.500
# 4                  496.56                   3   380000.0    267360      5.999
# ...                   ...                 ...        ...       ...        ...
# 248806               8.98                   4   456859.0    251834      2.250
# 248807             163.42                   4   968604.0    297350      2.250
# 248808              15.15                   2   410601.0    112868      2.250
# 248809              15.46                   6  1800000.0    308482      2.250
# 248810               4.15                   4   913719.0    333092      2.500
#
#         can_abi     symbol
# 0          True   DAI/USDT
# 1          True    MDX/BCH
# 2          True    MDX/DOT
# 3          True   MDX/USDT
# 4         False    MDX/ETH
# ...         ...        ...
# 248806    False    HT/USDT
# 248807     True  USDC/USDT
# 248808     True   LHB/USDT
# 248809    False   BTC/USDT
# 248810     True    HT/USDT
#
# [248811 rows x 14 columns]

# %%
np.corrcoef(df.gas_price, df.transferred_value)
# Out:
# array([[ 1.        , -0.00883828],
#        [-0.00883828,  1.        ]])

# %%
ht_gas.mean()
# Out:
# 12.270738502427701

# %%
df.gas_price.mean()
# Out:
# 17.034443048802057
